# %%
from instagrapi import Client

name = 'just_for_image_scraping'
password = '4X!v.!EudyvmEZ2'

cl = Client()
cl.login(name, password)
# Out:
# Code entered "520676" for just_for_image_scraping (0 attempts by 5 seconds)
# True

# %%
cl.dump_settings('dump.json')
cl.load_settings('dump.json')
user_id = cl.user_id_from_username(name)
medias = cl.user_medias(user_id, 20)

# %%
import json
import os
import datetime
import re
import time
import pprint

def datetime_handler(obj):
    """Convert datetime objects to string format before JSON serialization."""
    if isinstance(obj, datetime.datetime):
        return obj.isoformat()
    raise TypeError("Object type not serializable")


def get_post_data_and_extract_details(post_id):
    """
    Fetch post details and comments, then save them to a JSON file based on the organization's name.

    Parameters:
    - post_id: ID of the post to fetch details and comments for.
    """
    # convert the post id to post url
    post_url = f"https://www.instagram.com/p/{post_id}/"
    # media_pk = cl.media_pk_from_url(post_url)

### not wokring for some reason
    # Fetch media info and comments
    media_pk = cl.media_pk_from_code(post_id)
### not wokring for some reason

    try:
        media_info = cl.media_info(media_pk).dict()
    except:
        print(media_pk, '⚠️⚠️⚠️⚠️⚠️ WOOPS CRASHED!!!!  ⚠️⚠️⚠️⚠️⚠️')
        return None
    media_comments = cl.media_comments(media_pk)
    
    # Extract comment details and merge with media_info
    details = []
    for comment in media_comments:
        detail = {
            'pk': comment.pk,
            'text': comment.text,
            'username': comment.user.username,
            'full_name': comment.user.full_name,
            'profile_pic_url': comment.user.profile_pic_url,
            'created_at_utc': comment.created_at_utc,
            'content_type': comment.content_type,
            'status': comment.status,
            'has_liked': comment.has_liked,
            'like_count': comment.like_count,
            'post_id': media_info['id']
        }
        merged_data = {**detail, **media_info}
        details.append(merged_data)

    # Derive organization name from media_info's username
    org_name = media_info['user']['username']
    print(org_name)

    # Construct the file path based on org_name
    directory = 'org_post_comments'
    json_dump_loc = os.path.join(directory, f"{org_name}.json")

    # Ensure the directory exists
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Check if file exists, if so, load the existing data and append new data
    if os.path.exists(json_dump_loc):
        with open(json_dump_loc, 'r') as file:
            existing_data = json.load(file)
        existing_data.extend(details)
    else:
        existing_data = details

    # Write the combined data back to the file
    with open(json_dump_loc, 'w') as file:
        json.dump(existing_data, file, indent=4, default=datetime_handler)
    pprint.pprint(details)
    return details

# List all the files from the directory
files = os.listdir('companies_profile_HTML')

now_run = False
# Process each file
for file in files:
    if file.endswith(".html"):
        # Derive the company name from the filename
        company = file.replace('.html', '')

        # Open the HTML file and read its content
        with open(f'companies_profile_HTML\\{company}.html', 'r', encoding='utf-8') as html_file:
            content = html_file.read()

        # Use regex to find all patterns
        pattern = r'href="/p/([\w\d]+)/"'
        matches = re.findall(pattern, content)

        # Check if directory exists, and create if not
        output_dir = 'post_ids'
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        # Print matches for the current company
        print(f"Post IDs for {company}:")
        for match in matches:
            # print(match)
            # if match == 'CX3fWbHvcHr':
            #     now_run = True
            # elif now_run:pass
            # else:continue
            # print('hi')
            now_run = True
            if now_run:
                print(match)
                get_post_data_and_extract_details(match)
            # time.sleep(60)
            generate_random_time_and_sleep()
            # break 
        print("\n")

# get_post_data_and_extract_details('CY_CY2clulu')
# Out:
# Post IDs for hdfc:
# CY_CY2clulu
# hdfcbank
# [{'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 7, 12, 5, 43, 19, tzinfo=datetime.timezone.utc),
#   'full_name': 'Karan Sonawane',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/228446290_1046512009488520_572953686461486238_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=CO8b0c-eT_UAX8gu_k3&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA0q7hA5YUByOx2hCOmBGWGhLtvv7E7ZsraDfp7CKESDA&oe=64DA132F&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'HDFC BANK  is best bat hdfc bank branch service very bad 😔😔',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'karanbhoi724',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 30, 18, 37, 18, tzinfo=datetime.timezone.utc),
#   'full_name': 'sharuhasan',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/330839482_508327284779793_823261350584976939_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=Nw9BSVJg0OMAX8m_1kx&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfD533weBrBQhtwj4uLTeFXr6YXU_8zsOYe4KK48BD_GyQ&oe=64DAC0A5&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'I need some informations regarding my credit card bill, the payment '
#           "due haven't  updated yet.",
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'sharuhasan__',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 30, 18, 33, 56, tzinfo=datetime.timezone.utc),
#   'full_name': 'sharuhasan',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/330839482_508327284779793_823261350584976939_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=Nw9BSVJg0OMAX8m_1kx&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfD533weBrBQhtwj4uLTeFXr6YXU_8zsOYe4KK48BD_GyQ&oe=64DAC0A5&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': "@vikitamali I'm trying for almost a week, and it takes me to ivr "
#           'machines only,  worst customer service and bank ever.',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'sharuhasan__',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 30, 18, 28, 43, tzinfo=datetime.timezone.utc),
#   'full_name': 'Vikita Mali',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/328938936_977722503610189_6749750356664065932_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=pRDHvSe41ksAX-jPErc&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA2q43qqATQ-AxIEJDB04iTE3JnxrKBqSMFNTu2ytN_Yw&oe=64DA2F71&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': '@_sharu_hasan_ payment did get reflect. But still haven’t got a '
#           'chance to talk to their representative',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'vikitamali',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 30, 17, 53, 58, tzinfo=datetime.timezone.utc),
#   'full_name': 'sharuhasan',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/330839482_508327284779793_823261350584976939_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=Nw9BSVJg0OMAX8m_1kx&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfD533weBrBQhtwj4uLTeFXr6YXU_8zsOYe4KK48BD_GyQ&oe=64DAC0A5&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': '@vikitamali same issue, did you get it resolved?',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'sharuhasan__',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 29, 16, 49, 25, tzinfo=datetime.timezone.utc),
#   'full_name': 'rayankhan',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/364257833_198419426544637_7754629968220060862_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=rGd5jFULbCEAX-tFNOu&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA6rntv0VGUM4fh33BRtouYJLFK-Fn4Z9TwFW_UWRW_CQ&oe=64DAE06D&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': '@saurabhgoyal82  madarchod bank he bhaaai',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'rayanblaze',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 25, 7, 46, 20, tzinfo=datetime.timezone.utc),
#   'full_name': 'HDFC Bank',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA5lGC5QMjL3At_tu0gV1OuoMB01ouUNPwhuxJp7pQfwg&oe=64DAB981&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'Hi, we wish to confirm that we are in receipt of your payment of '
#           'RS.5858.00 and the payment has been posted to your card account on '
#           'January 22, 2022. \n'
#           'Your relationship is important to us. we request you to reconsider '
#           'your decision of closing the card account giving us an opportunity '
#           'to be of continuous service to you.  In the rare event if you gare '
#           'still contemplating card discontinuance, we request you to forward '
#           'us a duly signed request letter for card closure to the following '
#           'address to enable us do the needful.\n'
#           'HDFC Bank Cards Division\n'
#           'PO BOX # 8654\n'
#           'Thiruvanmiyur P.O.\n'
#           'Chennai 600 041 -Zubin',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'hdfcbank',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 15, 8, 11, tzinfo=datetime.timezone.utc),
#   'full_name': 'Vikita Mali',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/328938936_977722503610189_6749750356664065932_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=pRDHvSe41ksAX-jPErc&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA2q43qqATQ-AxIEJDB04iTE3JnxrKBqSMFNTu2ytN_Yw&oe=64DA2F71&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'I want someone to call me and help me resolve why is my payment not '
#           'reflecting and I want to close the credit card',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'vikitamali',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 15, 7, 38, tzinfo=datetime.timezone.utc),
#   'full_name': 'Vikita Mali',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/328938936_977722503610189_6749750356664065932_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=pRDHvSe41ksAX-jPErc&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA2q43qqATQ-AxIEJDB04iTE3JnxrKBqSMFNTu2ytN_Yw&oe=64DA2F71&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': '@hdfcbank my issue is not yet resolved. Have u guys fired all '
#           'employees and kept only recovery agents. I have paid my credit card '
#           'yet it’ shows unpaid and ur helpline doesn’t have option to talk to '
#           'any human . #worstbankever #fraudhdfc',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'vikitamali',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 10, 3, 44, tzinfo=datetime.timezone.utc),
#   'full_name': '丂卂卄丨ㄥ 爪卂卄ㄖㄒ尺卂',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/361329773_1403847223518990_8366869245705150854_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=106&_nc_ohc=gJ0z_U9FVScAX874C2e&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfCjUOakk7eYXjtBFLt4NFS_-SiT-hdJiV9NkzddsH1POA&oe=64DA37B2&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'Kabi bank wale bolte hai customer care coll kro customer care wale '
#           'bolte hai bank jao bad service seriously 😒',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'realsahilmahotra',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 10, 1, 33, tzinfo=datetime.timezone.utc),
#   'full_name': '丂卂卄丨ㄥ 爪卂卄ㄖㄒ尺卂',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/361329773_1403847223518990_8366869245705150854_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=106&_nc_ohc=gJ0z_U9FVScAX874C2e&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfCjUOakk7eYXjtBFLt4NFS_-SiT-hdJiV9NkzddsH1POA&oe=64DA37B2&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'bad service hdfc branch and  bad service customer care 😡😡😡😡😡',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'realsahilmahotra',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 9, 26, 8, tzinfo=datetime.timezone.utc),
#   'full_name': 'HDFC Bank',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA5lGC5QMjL3At_tu0gV1OuoMB01ouUNPwhuxJp7pQfwg&oe=64DAB981&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'Hi Abbas, please DM us the complete issue for better assistance. '
#           '-Anay',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'hdfcbank',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 8, 27, 15, tzinfo=datetime.timezone.utc),
#   'full_name': 'Abbas Abidi',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/361805544_191040143725965_5805000814115803603_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=a24Ta3-gibkAX9lXi98&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfCDQqbb8fIMqeMnOsq19sC_O49oDZ4w1-wIb6kq_y5FnQ&oe=64DA6BBE&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'Very bad experience hdfc Branch',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'abbas_aabidi',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 24, 2, 34, 8, tzinfo=datetime.timezone.utc),
#   'full_name': 'Rajesh Kumar',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78918925_2909653449079065_7338988722379030528_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=rYPpXEQoktkAX82biBP&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAbv5zOolzSXfRB5S6qnZhy9OpltFDHr1KfKc_s625BLw&oe=64DAE745&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'Writing on behalf of my sister \n'
#           'Jouthi Kumari - HDFC Housing Loan No - 668923058, Kadru, Ranchi '
#           'Branch, Jharkhand.\n'
#           "She applied for the Loan in October'21 which was disbursed on 19th "
#           "Jan'22 for an amount of 18 Lakhs. After clearing all the documents "
#           '& submitting them, after the disbursement of the Loan on 19th '
#           "Jan'22, they informed her to increase the loan amount from 18L to "
#           '23L. She was not told earlier and after agreeing to this, they '
#           'again started giving timelines that they fail to honour.\n'
#           'SM "Rajeev Nayan" Contact - 8825313700\n'
#           'Representative Allocated - "Dhanraj" Contact - 7903958088\n'
#           'My Concerns:\n'
#           'Ideally, HDFC should close this branch as they are not interested '
#           'in catering for their customers.\n'
#           'The process of loan guidance was wrong & even after agreeing to it, '
#           'they are taking their own sweet time.\n'
#           'It is an endless loop where HDFC seems like a fraud agency as they '
#           'have not even cleared the Rate of Interest yet even after '
#           'disbursement.\n'
#           ' \n'
#           'Kindly take action against these employees on papers to say so '
#           "since they don't work at all and don't honour any commitments. I "
#           'would not recommend HDFC as they are not reliable.',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'rajrichardson087',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 23, 7, 47, 8, tzinfo=datetime.timezone.utc),
#   'full_name': 'Trending Finance',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://scontent-sjc3-1.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-sjc3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=E8cry8APuaMAX_OkOHy&edm=AAAAAAABAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfCBbcjTZ-7-gOw2upTUdtG4arPIQz7TsalyXC03BZ8OrQ&oe=64DADF8F', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': 'For any kinds of Personal Loan with minimum % rate of interest '
#           '#doorstep #paperless banking ; Kindly Contact us .',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'trending.finance',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
#                   'Enjoy the freedom to invest, purchase, switch or redeem '
#                   'your mutual funds as you please.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#HDFCBank #MutualFunds #Wordle',
#   'clips_metadata': {},
#   'code': 'CY_CY2clulu',
#   'comment_count': 36,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2022, 1, 23, 4, 59, 8, tzinfo=datetime.timezone.utc),
#   'full_name': 'HDFC Bank',
#   'has_liked': None,
#   'id': '2755932000796207470_2308941538',
#   'image_versions2': {},
#   'like_count': 392,
#   'location': None,
#   'media_type': 1,
#   'pk': '2755932000796207470',
#   'play_count': None,
#   'post_id': '2755932000796207470_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA5lGC5QMjL3At_tu0gV1OuoMB01ouUNPwhuxJp7pQfwg&oe=64DAB981&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2022, 1, 21, 8, 11, 57, tzinfo=datetime.timezone.utc),
#   'text': '@vikitamali Hi, sorry to hear of your experience. Please DM us the '
#           'date/time of the call, the number you called with STD code, the '
#           'purpose of calling with your registered contact number. -Anay',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-15/272180183_115906210974496_1682153241474916556_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=x14Vu8JdUEcAX9Jov-6&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBYLy2FFDZ6aYc4pqvRqqskS0sWrVJUDm3nMx5eDDnQOg&oe=64DABF6B&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCAXmT8X7CIovV_EVnmMTSksG4bSe6giIbiuzUqawmM1w&oe=64DAB981&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'hdfcbank',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'Make Mutual Funds #DigitallyYours with an HDFC Bank '
#                   'Investment Services Account. \n'
#                   '\n'
#                   'Carry out transactions and have complete control over your '
#                   'Mutual Funds via NetBanking, \n'
#                   '\n'
# ...
#   'post_id': '2733594064759838485_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA5lGC5QMjL3At_tu0gV1OuoMB01ouUNPwhuxJp7pQfwg&oe=64DAB981&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2021, 12, 21, 12, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': 'Hi, please share with us the complete issue regarding charges along '
#           'with the details of the charges for better assistance. -Anay',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/269673834_640341053819497_8248809201556414061_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=2f75szs-jpoAX_j6J0m&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD2-rYCHFQvLkQ-5Rm6Q3nxgJ93t-z-QKMYJsVi_47ndQ&oe=64DA17D2&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'hdfcbank',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'A fraud shopping site not only cheats you through '
#                   'non-delivery of promised products, but it also captures '
#                   'your Debit/Credit card credentials and may misuse them. \n'
#                   '\n'
#                   'Practice #MoohBandhRakho when you come across unknown '
#                   'payment gateways and avoid sharing your banking details '
#                   'with fraudulent shopping websites.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#OnlineFraud\xa0#SecureBanking\xa0#BankSafe',
#   'clips_metadata': {},
#   'code': 'CXvrVGWIFcV',
#   'comment_count': 31,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2021, 12, 23, 8, 12, 52, tzinfo=datetime.timezone.utc),
#   'full_name': 'RITIKA KATHAIT🍁',
#   'has_liked': None,
#   'id': '2733594064759838485_2308941538',
#   'image_versions2': {},
#   'like_count': 422,
#   'location': None,
#   'media_type': 1,
#   'pk': '2733594064759838485',
#   'play_count': None,
#   'post_id': '2733594064759838485_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/333722490_5663958230368721_8760162060839258783_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=-7wWH5ZKvxEAX_g5Zd8&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfBVdnTwOmG7YYAfKew_-wL7qyKoXwvNpBTzTOc8cjl4CA&oe=64DB0DAA&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2021, 12, 21, 12, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': '@hdfcbank  As your team made the fake commitment it’s not cool at '
#           'all. There is unnecessarily charges had been charged to me without '
#           'any notifications.',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/269673834_640341053819497_8248809201556414061_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=2f75szs-jpoAX_j6J0m&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD2-rYCHFQvLkQ-5Rm6Q3nxgJ93t-z-QKMYJsVi_47ndQ&oe=64DA17D2&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'ritika629',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'A fraud shopping site not only cheats you through '
#                   'non-delivery of promised products, but it also captures '
#                   'your Debit/Credit card credentials and may misuse them. \n'
#                   '\n'
#                   'Practice #MoohBandhRakho when you come across unknown '
#                   'payment gateways and avoid sharing your banking details '
#                   'with fraudulent shopping websites.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#OnlineFraud\xa0#SecureBanking\xa0#BankSafe',
#   'clips_metadata': {},
#   'code': 'CXvrVGWIFcV',
#   'comment_count': 31,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2021, 12, 22, 9, 19, 11, tzinfo=datetime.timezone.utc),
#   'full_name': 'vikram jangir',
#   'has_liked': None,
#   'id': '2733594064759838485_2308941538',
#   'image_versions2': {},
#   'like_count': 422,
#   'location': None,
#   'media_type': 1,
#   'pk': '2733594064759838485',
#   'play_count': None,
#   'post_id': '2733594064759838485_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/321639828_719540136194864_5130142298384656830_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=n_xEX6vbToIAX_QtjW3&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDvV1lsWwgRVkt0263Mqav4EHw3IX76fgQ8P5CkJV5ZLg&oe=64DA082F&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2021, 12, 21, 12, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': 'Hello ,\n'
#           '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Any requirement for personal '
#           'loan. \n'
#           'HDFC/ICICI AND ALL BANKS \n'
#           '⭐⭐ Minimum interest rate 🌟🌟\n'
#           'document REQUIRED:-\n'
#           '👉 AADHAR CARD\n'
#           '👉 PAN CARD \n'
#           '👉 3 MONTHS SALARY SLEEP (minimum sellery 25k)\n'
#           '👉 6 MONTHS BANK STATEMENT \n'
#           '👉 FORM 16/ INCOME TAX FORM\n'
#           '\xa0\xa0 ONLY\xa0 \n'
#           'ANY OTHER ENQUIRE FINENESS RELATED PLEASE \n'
#           'contact 8302544414\n'
#           'VIKRAM JANGIR..',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/269673834_640341053819497_8248809201556414061_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=2f75szs-jpoAX_j6J0m&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD2-rYCHFQvLkQ-5Rm6Q3nxgJ93t-z-QKMYJsVi_47ndQ&oe=64DA17D2&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'vikramjangir__',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'A fraud shopping site not only cheats you through '
#                   'non-delivery of promised products, but it also captures '
#                   'your Debit/Credit card credentials and may misuse them. \n'
#                   '\n'
#                   'Practice #MoohBandhRakho when you come across unknown '
#                   'payment gateways and avoid sharing your banking details '
#                   'with fraudulent shopping websites.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#OnlineFraud\xa0#SecureBanking\xa0#BankSafe',
#   'clips_metadata': {},
#   'code': 'CXvrVGWIFcV',
#   'comment_count': 31,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2021, 12, 22, 9, 0, 22, tzinfo=datetime.timezone.utc),
#   'full_name': 'HDFC Bank',
#   'has_liked': None,
#   'id': '2733594064759838485_2308941538',
#   'image_versions2': {},
#   'like_count': 422,
#   'location': None,
#   'media_type': 1,
#   'pk': '2733594064759838485',
#   'play_count': None,
#   'post_id': '2733594064759838485_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=uwQ25z530SQAX-wFU31&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA5lGC5QMjL3At_tu0gV1OuoMB01ouUNPwhuxJp7pQfwg&oe=64DAB981&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2021, 12, 21, 12, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': "Hi Medha, if you have faced any issue with our service we'd like to "
#           'get it solved for you. Please share (via DM) your complete concern '
#           'for further assistance. -Anay',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/269673834_640341053819497_8248809201556414061_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=2f75szs-jpoAX_j6J0m&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD2-rYCHFQvLkQ-5Rm6Q3nxgJ93t-z-QKMYJsVi_47ndQ&oe=64DA17D2&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'hdfcbank',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0},
#  {'accessibility_caption': None,
#   'caption_text': 'A fraud shopping site not only cheats you through '
#                   'non-delivery of promised products, but it also captures '
#                   'your Debit/Credit card credentials and may misuse them. \n'
#                   '\n'
#                   'Practice #MoohBandhRakho when you come across unknown '
#                   'payment gateways and avoid sharing your banking details '
#                   'with fraudulent shopping websites.\n'
#                   '\n'
#                   'To know more, visit the link in bio.\n'
#                   '\n'
#                   '#OnlineFraud\xa0#SecureBanking\xa0#BankSafe',
#   'clips_metadata': {},
#   'code': 'CXvrVGWIFcV',
#   'comment_count': 31,
#   'commenting_disabled_for_viewer': False,
#   'comments_disabled': False,
#   'content_type': 'comment',
#   'created_at_utc': datetime.datetime(2021, 12, 22, 8, 40, 41, tzinfo=datetime.timezone.utc),
#   'full_name': 'Dr Medha Ganesh Naik',
#   'has_liked': None,
#   'id': '2733594064759838485_2308941538',
#   'image_versions2': {},
#   'like_count': 422,
#   'location': None,
#   'media_type': 1,
#   'pk': '2733594064759838485',
#   'play_count': None,
#   'post_id': '2733594064759838485_2308941538',
#   'product_type': '',
#   'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/366506072_1422012028363153_6960016217775998670_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=UzdCftZcWpgAX9nGsYa&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDC9e4-BFuFW5lZ72P5u65psMz4Bq6sn6D9z5gsEsbPtQ&oe=64D94649&_nc_sid=f5838a', ),
#   'resources': [],
#   'sponsor_tags': [],
#   'status': 'Active',
#   'taken_at': datetime.datetime(2021, 12, 21, 12, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': '@hdfcbank is the biggest fraud bank',
#   'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/269673834_640341053819497_8248809201556414061_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=2f75szs-jpoAX_j6J0m&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD2-rYCHFQvLkQ-5Rm6Q3nxgJ93t-z-QKMYJsVi_47ndQ&oe=64DA17D2&_nc_sid=2999b8', ),
#   'title': '',
#   'user': {'full_name': 'HDFC Bank',
#            'is_private': False,
#            'pk': '2308941538',
#            'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ),
#            'profile_pic_url_hd': None,
#            'stories': [],
#            'username': 'hdfcbank'},
#   'username': 'medha.naik',
#   'usertags': [],
#   'video_duration': 0.0,
#   'video_url': None,
#   'view_count': 0}]
# Going to sleep for 00:18:129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 3 in <cell line: 88>()
#     <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=117'>118</a>         get_post_data_and_extract_details(match)
#     <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=118'>119</a>     # time.sleep(60)
# --> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=119'>120</a>     generate_random_time_and_sleep(10)
#     <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=120'>121</a>     # break
#     <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=121'>122</a> print("\n")
#
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 3 in generate_random_time_and_sleep(input_seconds)
#      <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=15'>16</a> print(sleep_message)
#      <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=17'>18</a> # Sleep for the calculated duration
# ---> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=18'>19</a> time.sleep(total_sleep_time)
#      <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X51sZmlsZQ%3D%3D?line=20'>21</a> return f"Slept for {minutes:02}:{seconds:02}:{milliseconds:03}"
#
# KeyboardInterrupt:

# %%
import random
import time
def generate_random_time_and_sleep(input_seconds):
    """Generate a random time based on the input seconds, print the sleep duration, and then sleep for that duration."""
    
    # Calculate minutes and seconds from input_seconds
    minutes = input_seconds // 60
    seconds = input_seconds % 60 + random.randint(3, 10)  # Adding a random value between 3-10 to the seconds
    milliseconds = random.randint(0, 999)
    
    # Calculate total time to sleep in seconds (including milliseconds)
    total_sleep_time = minutes * 60 + seconds + milliseconds / 1000.0
    
    # Print the calculated sleep duration
    sleep_message = f"Going to sleep for {minutes:02}:{seconds:02}:{milliseconds:03}"
    print(sleep_message)
    
    # Sleep for the calculated duration
    time.sleep(total_sleep_time)
    
    # return f"Slept for {minutes:02}:{seconds:02}:{milliseconds:03}"

# Note: Avoid running this function here due to the sleep duration. Run it in your local environment instead.

generate_random_time_and_sleep(10)
# Out:
# Going to sleep for 00:17:244
# 'Slept for 00:17:244'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> details = [{'pk': '2736394837655183720', 'text': 'Credit card available ..?', 'username': 'kartik_0247', 'full_name': 'Kartik Premji Chheda', 'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/271887522_224996293057845_5346076759909609230_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=QvJc3k-evxEAX8vGRM8&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfA-ytGJFv3Elbj_Jw7gdG-3MW0jY0U0s5LLw86xwkp7Pg&oe=64D90EB6&_nc_sid=f5838a', ), 'created_at_utc': datetime.datetime(2022, 6, 20, 11, 21, 37, tzinfo=datetime.timezone.utc), 'content_type': 'comment', 'status': 'Active', 'has_liked': None, 'like_count': 1675, 'post_id': '2736394837655183720_2308941538', 'id': '2736394837655183720_2308941538', 'code': 'CX5oJtXpmFo', 'taken_at': datetime.datetime(2021, 12, 25, 9, 15, 10, tzinfo=datetime.timezone.utc), 'media_type': 2, 'image_versions2': {}, 'product_type': 'feed', 'thumbnail_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/270016371_456069219234288_7216450494134410513_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=-1CzShAmVtAAX-sEv03&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfB820MNszzL2r1zADbU9Xeul6BsZ0PebI0_rye1DW1bBg&oe=64D66F7C&_nc_sid=2999b8', ), 'location': None, 'user': {'pk': '2308941538', 'username': 'hdfcbank', 'full_name': 'HDFC Bank', 'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX9551rw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAetXhpL5CzKYTFo1BBxvKhpIvqdjXqTCqHXiH3IsqaWQ&oe=64D8BF41&_nc_sid=2999b8', ), 'profile_pic_url_hd': None, 'is_private': False, 'stories': []}, 'comment_count': 30, 'comments_disabled': False, 'commenting_disabled_for_viewer': False, 'play_count': None, 'caption_text': "Sending good wishes and cheer your way for the most wonderful time of the year! \n\nHere's to a secure future filled with good fortune and renewed hope. \n\nWe wish you a Merry Christmas and Happy Holidays 🎄\n\n#MerryChristmas #HDFCBank", 'accessibility_caption': None, 'usertags': [], 'sponsor_tags': [], 'video_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t50.2886-16/269994162_439261321076870_4529413877019464736_n.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5mZWVkLmRlZmF1bHQiLCJxZV9ncm91cHMiOiJbXCJpZ193ZWJfZGVsaXZlcnlfdnRzX290ZlwiXSJ9&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=MLkMrPIzeWgAX9_J9gB&edm=AP_V10EBAAAA&vs=17913105266276667_3342891252&_nc_vs=HBksFQAYJEdMTElGeENHb0FGLWdZOEJBQ0JVZUZ6c3Rkc19ia1lMQUFBRhUAAsgBABUAGCRHQmcyRkJCeWI1UEZDSXNGQVBRelN6MXlZenRfYmtZTEFBQUYVAgLIAQAoABgAGwAVAAAmhNO86K3h3z8VAigCQzMsF0AnEOVgQYk3GBJkYXNoX2Jhc2VsaW5lXzFfdjERAHXqBwA%3D&ccb=7-5&oh=00_AfBIV5VfGsVWvFRfRLxRGgdSogDCOz7aXPUlRP4Ot7Q9OQ&oe=64D61EE9&_nc_sid=2999b8', ), 'view_count': 14318, 'video_duration': 11.533, 'title': '', 'resources': [], 'clips_metadata': {}}, {'pk': '2736394837655183720', 'text': 'Hello guys.... Anyone interested for personal or business loan.... So plzz contact me....', 'username': 'singhaniya6382', 'full_name': 'Sanjay Jatoliya', 'profile_pic_url': HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/315965587_662221768971793_6715372273953319306_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=i2FbwI-sgXcAX9Wkdr7&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfBrnJaS4CZSLjSwiduqnlwsaYqbX3NSPY37HMxMdGmjCA&oe=64D8BB8F&_nc_sid=f5838a', ), 'created_at_utc': datetime.datetime(2022, 2, 16, 10, 49, 1, tzinfo=datetime.timezone.utc), 'content_type': 'comment', 'status': 'Active', 'has_liked': None, 'like_count': 1675, 'post_id': '2736394837655183720_2308941538', 'id': '2736394837655183720_2308941538', 'code': 'CX5oJtXpmFo', 'taken_at': date ...
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> pprint.pprint(details)
#
# NameError: name 'HttpUrl' is not defined

# %%
# # trying
# post_id = 'CY9Ip2qqvrt'

# code = cl.media_pk(post_id)
# cl.media_info(code)

# %%
# import os
# import re

# company = 'sbi'

# # Open the HTML file and read its content
# with open(f'companies_profile_HTML\\{company}.html', 'r', encoding='utf-8') as hdfc:
#     content = hdfc.read()

# # Use regex to find all patterns
# pattern = r'href="/p/([\w\d]+)/"'
# matches = re.findall(pattern, content)

# # Check if directory exists, and create if not
# output_dir = 'post_ids'
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Save matches to a file
# for match in matches:
#     print(match)

import os
import re

# List all the files from the directory
files = os.listdir('companies_profile_HTML')

# Process each file
for file in files:
    if file.endswith(".html"):
        # Derive the company name from the filename
        company = file.replace('.html', '')

        # Open the HTML file and read its content
        with open(f'companies_profile_HTML\\{company}.html', 'r', encoding='utf-8') as html_file:
            content = html_file.read()

        # Use regex to find all patterns
        pattern = r'href="/p/([\w\d]+)/"'
        matches = re.findall(pattern, content)

        # Check if directory exists, and create if not
        output_dir = 'post_ids'
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        # Print matches for the current company
        print(f"Post IDs for {company}:")
        for match in matches:
            print(match)
        print("\n")
        get_post_data_and_extract_details(company)
# Out:
# Post IDs for hdfc:
# CY_CY2clulu
# CY9Ip2qqvrt
# CY3oCHQoUvs
# CY1qCKyIy1H
# CYt2ovfIlRw
# CYqo_zHIW2B
# CYqLz2VIKKZ
# CYmIE56IV6j
# CYY9NOnIFM6
# CYVsgvzoLmH
# CYT8k5LIHRK
# CYGdZ7KoqaX
# CYECNvWowX2
# CYBndaAoZHZ
# CX5oJtXpmFo
# CX3fWbHvcHr
# CX2r_DDoJDK
# CXyYv5BoX5n
# CXvrVGWIFcV
# CXtYLY6o0oz
# CXnqjKaIxV_
# CXi3hv3Inyy
# CXgf2wFoTiZ
# CXftnJ4Lu6z
# CXaizgoo6_P
# CXV4Xu9o4V3
# CXTZTWJoAKT
# CXQY_rwIQh9
# CXNaqQZoZGv
# CXLQUo5Bsrc
# CXIQhJDor6U
# CXAo4uCq3em
# CW41w9qK7lh
# CW2R2GEKQpY
# CWvAYBJNxkV
# CWqcKSoq8fj
# CWnaQ8pqRNL
# CWm1H0DqOTc
# CWkVCSmrPIA
# CWdAwRntUPu
# CWczYZkl6JW
# CWXjaCkrkU5
# CWVtQE8FsoR
# CWS7dbGKqKi
# CWOJe2aqHtz
# CWNL4f1IIp2
# CWIzZXQJhuK
# CWFVZEcKQCp
# CWC3naht_0c
# CVwpafhFxH2
# CVvMbpGKsA6
# CVuMPeCKYB7
# CVr5lOfrcJu
# CVpwnDnKVoc

# %%
import json
import os

def extract_comment_details(comments, media_info, json_dump_loc):
    """
    Extract key details from a list of comments, merge with media info, 
    and save them to a JSON file.

    Parameters:
    - comments: List of Comment objects.
    - media_info: Dictionary containing media post details.
    - json_dump_loc: Location of the JSON file to dump the data.

    Returns:
    - A list of dictionaries, each containing key details from a comment merged with media info.
    """
    details = []

    for comment in comments:
        detail = {
            'pk': comment.pk,
            'text': comment.text,
            'username': comment.user.username,
            'full_name': comment.user.full_name,
            'profile_pic_url': comment.user.profile_pic_url,
            'created_at_utc': comment.created_at_utc,
            'content_type': comment.content_type,
            'status': comment.status,
            'has_liked': comment.has_liked,
            'like_count': comment.like_count,
            'post_id': media_info['id']
        }

        # Merge comment details with media_info
        merged_data = {**detail, **media_info}
        details.append(merged_data)

    # Check if file exists, if so, load the existing data and append new data
    if os.path.exists(json_dump_loc):
        with open(json_dump_loc, 'r') as file:
            existing_data = json.load(file)
        existing_data.extend(details)
    else:
        existing_data = details

    # Write the combined data back to the file
    with open(json_dump_loc, 'w') as file:
        json.dump(existing_data, file, indent=4)

    return details

# %%
import json
import os

def extract_comment_details(comments, post_id, json_dump_loc):
    """
    Extract key details from a list of comments and save them to a JSON file.

    Parameters:
    - comments: List of Comment objects.
    - post_id: ID of the post the comments belong to.
    - json_dump_loc: Location of the JSON file to dump the data.

    Returns:
    - A list of dictionaries, each containing key details from a comment.
    """
    details = []

    for comment in comments:
        detail = {
            'pk': comment.pk,
            'text': comment.text,
            'username': comment.user.username,
            'full_name': comment.user.full_name,
            'profile_pic_url': comment.user.profile_pic_url,
            'created_at_utc': comment.created_at_utc,
            'content_type': comment.content_type,
            'status': comment.status,
            'has_liked': comment.has_liked,
            'like_count': comment.like_count,
            'post_id': post_id
        }
        details.append(detail)

    # Check if file exists, if so, load the existing data and append new data
    if os.path.exists(json_dump_loc):
        with open(json_dump_loc, 'r') as file:
            existing_data = json.load(file)
        existing_data.extend(details)
    else:
        existing_data = details

    # Write the combined data back to the file
    with open(json_dump_loc, 'w') as file:
        json.dump(existing_data, file, indent=4)

    return details


extract_comment_details(comments, 'CoFIKqvt8w4', 'comment_data_for_json_dump')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 4 in <cell line: 49>()
#      <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X54sZmlsZQ%3D%3D?line=43'>44</a>         json.dump(existing_data, file, indent=4)
#      <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X54sZmlsZQ%3D%3D?line=45'>46</a>     return details
# ---> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X54sZmlsZQ%3D%3D?line=48'>49</a> extract_comment_details(comments, 'CoFIKqvt8w4')
#
# TypeError: extract_comment_details() missing 1 required positional argument: 'json_dump_loc'

# %%
def extract_comment_details(comments):
    """
    Extract key details from a list of comments.

    Parameters:
    - comments: List of Comment objects.

    Returns:
    - A list of dictionaries, each containing key details from a comment.
    """
    details = []

    for comment in comments:
        detail = {
            'pk': comment.pk,
            'text': comment.text,
            'username': comment.user.username,
            'full_name': comment.user.full_name,
            'profile_pic_url': comment.user.profile_pic_url,
            'created_at_utc': comment.created_at_utc,
            'content_type': comment.content_type,
            'status': comment.status,
            'has_liked': comment.has_liked,
            'like_count': comment.like_count
        }
        details.append(detail)
    
    return details

# %%
import datetime


import pprint as pp
pp.pprint(lisy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> import datetime
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> lis = {'pk': '3027862241941113912', 'id': '3027862241941113912_4273886000', 'code': 'CoFIKqvt8w4', 'taken_at': datetime.datetime(2023, 1, 31, 12, 48, 48, tzinfo=datetime.timezone.utc), 'media_type': 1, 'image_versions2': {}, 'product_type': '', 'thumbnail_url': 'https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-15/328244256_1555680471601695_3604951277799089138_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=Z1KwtHNYoQYAX9d9Ysv&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAdyO-jEBsum3K_VoCxYzmfbM8eh27dOBbx7LLfZD1NCg&oe=64D9739D&_nc_sid=2999b8', 'location': None, 'user': {'pk': '4273886000', 'username': 'sbicard_connect', 'full_name': 'SBI Card', 'profile_pic_url': 'https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/51455042_637761470011846_532169851251195904_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=h43Q-4bsuxEAX_dhSP7&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBs4RTHa617fFGSXlnOol8MlGZBE8SrIPUsKTBcc8t2DA&oe=64DA5405&_nc_sid=2999b8', 'profile_pic_url_hd': None, 'is_private': False, 'stories': []}, 'comment_count': 42, 'comments_disabled': False, 'commenting_disabled_for_viewer': False, 'like_count': 724, 'play_count': None, 'has_liked': None, 'caption_text': 'A complimentary Noise ColorFit Pulse 2 Max Smart Watch*, 1 year complimentary FITPASS PRO, and Netmeds First membership*. Get your SBI Card Pulse now!\n\nVisit SBI Card website to apply now.\n\n*T&C Apply\n\n#SBICard #SBICardPulse #Pulse #fitness', 'accessibility_caption': None, 'usertags': [], 'sponsor_tags': [], 'video_url': None, 'view_count': 0, 'video_duration': 0.0, 'title': '', 'resources': [], 'clips_metadata': {}}
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> lisy = [Comment(pk='18350058619056971', text='Dear sbi i would request you to stop doing fraud  i have been alredy cheated by your companay still they are calling me to trap with your credit card', user=UserShort(pk='12153889458', username='arifalishah04', full_name='ARIFALI OFFICIAL', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/174205610_134454008652989_8344061990798577909_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=DF3CLOfVIAIAX8HpsCB&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAFXh82GZhMC0imC6lAsKRKrAxWlKztgvsG0upu74AI-Q&oe=64D8BC14&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]), created_at_utc=datetime.datetime(2023, 3, 17, 13, 57, 43, tzinfo=datetime.timezone.utc), content_type='comment', status='Active', has_liked=False, like_count=1), Comment(pk='17973138557156023', text='@sbicard_connect i think they will not  contact me be  they have been xposed with sbi as well', user=UserShort(pk='12153889458', username='arifalishah04', full_name='ARIFALI OFFICIAL', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/174205610_134454008652989_8344061990798577909_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=DF3CLOfVIAIAX8HpsCB&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAFXh82GZhMC0imC6lAsKRKrAxWlKztgvsG0upu74AI-Q&oe=64D8BC14&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]), created_at_utc=datetime.datetime(2023, 3, 16, 12, 15, 26, tzinfo=datetime.timezone.utc), content_type='comment', status='Active', has_liked=None, like_count=None), Comment(pk='17982509338845509', text='@arifalishah04 For security reasons, please remove the comment that contains your contact information urgently, as it can pose a security concern later. Thank you for providing your contact details. We will contact you at the earliest.', user=UserShort(pk='4273886000', username='sbicard_connect', full_name='SBI Card', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/51455042_637761470011846_532169851251195904_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=h43Q-4bsuxEAX_dhSP7&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfBANQl8FsRb-15TPZDx1TZsXDcKj_ozlUvVIbfLmAUWMQ&oe=64DA5405&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]), created_at_utc=datetime.datetime(2023, 3, 16, 12, 13, 27, tzinfo=datetime.timezone.utc), content_type='comment', status='Active', has_liked=None, like_count=None), Comment(pk='17956996085406178', text='@sbicard_connect even first told me  it will be FOC  but they charged 1500', user=UserShort(pk='12153889458', username='arifalishah04', full_name='ARIFALI OFFICIAL', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/174205610_134454008652989_8344061990798577909_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=DF3CLOfVIAIAX8HpsCB&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAFXh82GZhMC0imC6lAsKRKrAxWlKztgvsG0upu74AI-Q&oe=64D8BC14&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]), created_at_utc=datetime.datetime(2023, 3, 16, 12, 12, 55, tzinfo=datetime.timezone.utc), content_type='comment', status='Active', has_liked=None, like_count=None), Comment(pk='17957435675455744', text='@arifalishah04 Hi, we regret for the inconvenience caused to you. Please provide me with your contact details via private message and our team would be happy to assist you.', user=UserShort(pk='4273886000', username='sbicard_connect', full_name='SBI Card', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/51455042_637761470011846_532169851251195904_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=h43Q-4bsuxEAX_dhSP7&edm=AId3EpQBA ...
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> import pprint as pp
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X52sZmlsZQ%3D%3D?line=6'>7</a> pp.pprint(lisy)
#
# NameError: name 'Comment' is not defined

# %%
# cl.load_settings('dump.json')

# %%
# cl.media_pk_from_url('https://www.instagram.com/p/Cvj02kgxvVx')

# %%
import re

def get_hashtags(text):
    # Using regular expression to find hashtags
    hashtags = re.findall(r'#\w+', text)
    return hashtags

def format_datetime_to_utc_iso(datetime_obj):
    # Convert the datetime to the desired format
    formatted_datetime = datetime_obj.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
    return formatted_datetime

    return iso8601_string
def convert_data(data):
    # initialize an empty dictionary to store the converted data
    converted_data = {}
    # loop through the data items and assign them to the corresponding keys
    for key, value in data.items():
        if key == 'pk':
            converted_data['id'] = value
        elif key == 'media_type':
            converted_data['type'] = 'image' if value == 1 else 'video'
        elif key == 'code':
            converted_data['shortCode'] = value
        elif key == 'caption_text':
            converted_data['caption'] = value
        elif key == 'usertags':
            converted_data['hashtags'] = value
        elif key == 'user':
            converted_data['url'] = value.profile_pic_url
            converted_data['ownerFullName'] = value.full_name
            converted_data['ownerUsername'] = value.username
            converted_data['ownerId'] = value.pk
        elif key == 'comment_count':
            converted_data['commentsCount'] = value
        elif key == 'like_count':
            converted_data['likesCount'] = value
        elif key == 'play_count':
            converted_data['videoPlayCount'] = value
        elif key == 'video_url':
            converted_data['videoUrl'] = value
        elif key == 'view_count':
            converted_data['videoViewCount'] = value
        elif key == 'taken_at':
            converted_data['timestamp'] = format_datetime_to_utc_iso(value)
        elif key == 'resources':
            converted_data['images'] = [resource.thumbnail_url[:] for resource in value]
        elif key == 'product_type':
            converted_data['productType'] = value
        elif key == 'video_duration':
            converted_data['videoDuration'] = value
        elif key == 'sponsor_tags':
            converted_data['isSponsored'] = len(value) > 0

    # set some default values for the keys that are not in the data
    converted_data['firstComment'] = ''
    converted_data['lastestComments'] = []
    # converted_data['alt'] = ''
    # converted_data['childPosts'] = []
    converted_data['hashtags'] = get_hashtags(converted_data['caption'])
    # print(convert_data['hashtags'])
    # initialize an empty list to store the ordered keys
    ordered_keys = ['id', 'type', 'shortCode', 'caption', 'hashtags', 
                    'mentions', 'url', 'commentsCount', 'firstComment', 
                    'latestComments', 'dimensionsHeight', 'dimensionsWidth', 
                    'displayUrl', 'images', 'videoUrl', 'alt', 
                    'likesCount', 'videoViewCount', 'videoPlayCount', 
                    'timestamp', 'childPosts', 
                    'ownerFullName', 'ownerUsername', 
                    'ownerId', 'productType', 
                    'videoDuration', 
                    'isSponsored']
    # initialize an empty list to store the ordered data items as tuples of (key, value)
    ordered_items = []
    # loop through the ordered keys and add them to the ordered items list with their values from the converted data
    for key in ordered_keys:
        if key in converted_data:
            ordered_items.append((key, converted_data[key]))
        else:
            ordered_items.append((key, None))

    # return the ordered data as a dictionary by using the dict() constructor on the ordered items list
    return dict(ordered_items)

convert_data(info)

data = convert_data(info)
# data

# %%
# for i in range(len(Posts_info_required_format)):
#     print(Posts_info_required_format[i])
#     Posts_info_required_format[i]['firstComment']=each_post_comments_list[i][0]
#     Posts_info_required_format[i]['latestComments']=each_post_comments_list[i]

# Posts_info_required_format

# %%
# Out:
# True

# %%
the_post = 'https://www.instagram.com/p/CY_CY2clulu/'

cl.media_pk_from_url(the_post)
# Out:
# 2755932000796207470

# %%
cl.media_info("3163129172227096711")
# Out:
# Media(pk='3163129172227096711', id='3163129172227096711_2308941538', code='CvlsTkhRYCH', taken_at=datetime.datetime(2023, 8, 6, 4, 0, 3, tzinfo=datetime.timezone.utc), media_type=8, image_versions2={}, product_type='', thumbnail_url=None, location=None, user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel27-4.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel27-4.fna.fbcdn.net&_nc_cat=100&_nc_ohc=3dm42uXrss8AX8vtIhT&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfClqaXRYDjk_f2cqNzd9NhDFK5wtv2EtO1VhQNZ_UFEiA&oe=64D8BF41&_nc_sid=2999b8', ), profile_pic_url_hd=None, is_private=False, stories=[]), comment_count=35, comments_disabled=False, commenting_disabled_for_viewer=False, like_count=2144, play_count=None, has_liked=None, caption_text='Here’s to the Honest, Dependable, Forgiving and Caring friends who have always got your back.\n\nHDFC Bank wishes everyone a Happy #FriendshipDay!\n\n#HDFCBank #Finance #Eva #ChatBanking #ATM #Loans #FriendshipDay2023 #FriendsForever #BestFriends #BFFs #FriendshipGoals', accessibility_caption=None, usertags=[], sponsor_tags=[], video_url=None, view_count=0, video_duration=0.0, title='', resources=[Resource(pk='3163129167135113450', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/365104579_18343091032077539_3113699458474607986_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=d-noWWsl2OYAX8KZ-zg&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfCBNeplp2udl_XSsVdmt7LXSpoepS_AntDkvnnv5V1Vvg&oe=64D89EF4&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126787788', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/365568294_18343091023077539_4460791001627051598_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=8lfdkHNQxhEAX9dTdJ5&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfAxiWYKNWWCACrRg7kibq4kDW85AAOntmgbv5jOlu5rkw&oe=64D7812B&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126740579', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/366014097_18343091005077539_1792443675125470569_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=OdcKkwBWUsIAX_yL09D&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfDnaZnCnqqZ6E8n6hGax_arDo5lnhThxC_AQxFt5cdw4w&oe=64D8CE72&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126964860', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/362959204_18343091014077539_8047482118074979082_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=hPL0sEY5uo8AX9aOpl0&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfDznDOZH4iE9EORyPXnWzaD4IiAiF2TcjXNhChrW13ASg&oe=64D8811C&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126928779', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/362968114_18343091059077539_7987510554069790927_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=j-Vvl3QO8UQAX8Mw-cu&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfDt9vAorpEr2gIpzbbD3yV6RCsWrcgg6lgaW70N5RI43w&oe=64D8A2F7&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167135307243', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/363420189_18343091041077539_5001150988479949507_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=77jmA4uTgHAAX-lUhTF&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfDgqddBTjNX4HednMHk42AQMiTRBuqxxcW7FnH_ldZ79w&oe=64D828B3&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167152133577', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel27-1.fna.fbcdn.net/v/t39.30808-6/362695343_18343091050077539_726106839180486155_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht ...

# %%
# insta posts links
meida_links = [
        # 'https://www.instagram.com/p/CvlsTkhRYCH',
         "https://www.instagram.com/p/Cvj02kgxvVx", 'https://www.instagram.com/p/CvhhQc0upI5', 'https://www.instagram.com/p/CvhWl4Br9hi']


media_ids = []
# posts_id
for meida_link in meida_links:
    print(meida_link)
    medias_id = cl.media_pk_from_url(i)
    media_ids.append(medias_id)
# Out:
# [3163129172227096711, 3162603811819156849, 3161954679386706489, 3161907773192525922]

# %%
meida_ids = [3163129172227096711, 3162603811819156849, 3161954679386706489, 3161907773192525922]

# %%
# gettings each media comment data
# each_post_comments = []
for i in meida_ids:    
    print(f'getting comment data for {i} id')
    # post_comments.append(cl.media_comments(i))
# Out:
# getting comment data for 3163129172227096711 id
# getting comment data for 3162603811819156849 id
# getting comment data for 3161954679386706489 id
# getting comment data for 3161907773192525922 id

# %%
meida = meida_ids[0]

info = cl.media_info(3163129172227096711)

# %%
each_post_comments_list = []
for comments in each_post_comments:
    post = []
    for comment in comments:
        # print((comment.text))
        post.append(comment.text)
    each_post_comments_list.append(post)
# each_post_comments_list

# %%
Posts_info_required_format = []
for post in posts_info:
    post_dict = convert_data(dict(post))
    print(post_dict)
    Posts_info_required_format.append(post_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\saket\Documents\GitHub\Pyhton\INTERNSHALA\scrape insta with api.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> Posts_info_required_format = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> for post in posts_info:
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     post_dict = convert_data(dict(post))
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/Documents/GitHub/Pyhton/INTERNSHALA/scrape%20insta%20with%20api.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     print(post_dict)
#
# NameError: name 'posts_info' is not defined

# %%
# posts_info = []
# media_ids = [3163129172227096711, 3162603811819156849, 3161954679386706489, 3161907773192525922]


# for media_id in media_ids:
#     print(media_id)
#     post_info = cl.media_info(media_id)
#     posts_info.append(post_info)

# %%
json_data = json.dumps(Posts_info_required_format, indent=4)

# add it to a json file

with open('posts_info.json', 'w') as json_file:
    json_file.write(json_data)

# %%
# each_post_comments_list

# %%
# Convert the dictionary to a JSON string
json_string = json.dumps(data, indent=4)

# Save the JSON data to a file named "test.json"
with open("test.json", "w") as json_file:
    json_file.write(json_string)

print("Data saved to test.json")
# Out:
# Data saved to test.json

# %%
print(info)
# Evaluating the content to convert it into a Python object
# data = eval(info)
post_data = []
# Converting the list of tuples into a dictionary for easier access
info = dict(info)
# Out:
# {'pk': '3163129172227096711', 'id': '3163129172227096711_2308941538', 'code': 'CvlsTkhRYCH', 'taken_at': datetime.datetime(2023, 8, 6, 4, 0, 3, tzinfo=datetime.timezone.utc), 'media_type': 8, 'image_versions2': {}, 'product_type': '', 'thumbnail_url': None, 'location': None, 'user': UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBBNFEQGUVllxIy_HTmLPzNn096NK37L6O_eMwC0fTFgQ&oe=64D4CAC1&_nc_sid=2999b8', ), profile_pic_url_hd=None, is_private=False, stories=[]), 'comment_count': 22, 'comments_disabled': False, 'commenting_disabled_for_viewer': False, 'like_count': 2008, 'play_count': None, 'has_liked': None, 'caption_text': 'Here’s to the Honest, Dependable, Forgiving and Caring friends who have always got your back.\n\nHDFC Bank wishes everyone a Happy #FriendshipDay!\n\n#HDFCBank #Finance #Eva #ChatBanking #ATM #Loans #FriendshipDay2023 #FriendsForever #BestFriends #BFFs #FriendshipGoals', 'accessibility_caption': None, 'usertags': [], 'sponsor_tags': [], 'video_url': None, 'view_count': 0, 'video_duration': 0.0, 'title': '', 'resources': [Resource(pk='3163129167135113450', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/365104579_18343091032077539_3113699458474607986_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=YflsWVW669IAX_cLTll&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfAVfkp_xYcVE2s4n539Ok9lhpitwYZRpfprRQ2acMB-tg&oe=64D6A4B4&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126787788', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/365568294_18343091023077539_4460791001627051598_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=ZQz0i-rnBUAAX-Yzv8Z&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfC51oBT3htu7KX0O_Tf54xaXybmlQpQv0XD7ON0q5ha_g&oe=64D586EB&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126740579', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/366014097_18343091005077539_1792443675125470569_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=OdcKkwBWUsIAX8urvNt&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfAqVygZYFjz6DvLHlDvtfY5UQbg9xDQt-3hsSlhtvd6gg&oe=64D4D9F2&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126964860', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/362959204_18343091014077539_8047482118074979082_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=hPL0sEY5uo8AX92YM9t&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfDhvaJMNI00dK2FpP9vJmUdfAK99Wn7Du74C2ruQ3ExTA&oe=64D686DC&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167126928779', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/362968114_18343091059077539_7987510554069790927_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=uBzqiJ0Wd_8AX8i-FWU&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfBYmUfUFJwReVAsBxGUth2gPthVPhKsuyWKwcRdf_Gbbw&oe=64D4AE77&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167135307243', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/363420189_18343091041077539_5001150988479949507_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=77jmA4uTgHAAX_er8do&edm=AP_V10EAAAAA&ccb=7-5&oh=00_AfD0vEHvX5gT7pR180j_AVXSsSXP13oM6fxATNB2_fQkNQ&oe=64D62E73&_nc_sid=2999b8', ), media_type=1), Resource(pk='3163129167152133577', video_url=None, thumbnail_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t39.30808-6/362695343_18343091050077539_726106 ...

# %%
import pprint
# pprint.pprint()
for i in each_post_comments[0][0]:
    print(i)
# Out:
# ('pk', '17974598969296930')
# ('text', 'Hi Arpita, I have noted your concern. I will check the details on this and update you. Request your patience in the interim. -Ajay, Service Manager')
# ('user', UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]))
# ('created_at_utc', datetime.datetime(2023, 8, 7, 9, 42, 52, tzinfo=datetime.timezone.utc))
# ('content_type', 'comment')
# ('status', 'Active')
# ('has_liked', None)
# ('like_count', None)

# %%
posts_info
# Out:
# []

# %%
# Out:
# 3163129172227096711
# 3162603811819156849
# 3161954679386706489
# 3161907773192525922

# %%
import re

def get_hashtags(text):
    # Using regular expression to find hashtags
    hashtags = re.findall(r'#\w+', text)
    return hashtags

def format_datetime_to_utc_iso(datetime_obj):
    # Convert the datetime to the desired format
    formatted_datetime = datetime_obj.strftime("%Y-%m-%dT%H:%M:%S.%fZ")
    return formatted_datetime

    return iso8601_string
def convert_data(data):
    # initialize an empty dictionary to store the converted data
    converted_data = {}
    # loop through the data items and assign them to the corresponding keys
    for key, value in data.items():
        if key == 'pk':
            converted_data['id'] = value
        elif key == 'media_type':
            converted_data['type'] = 'image' if value == 1 else 'video'
        elif key == 'code':
            converted_data['shortCode'] = value
        elif key == 'caption_text':
            converted_data['caption'] = value
        elif key == 'usertags':
            converted_data['hashtags'] = value
        elif key == 'user':
            converted_data['url'] = value.profile_pic_url
            converted_data['ownerFullName'] = value.full_name
            converted_data['ownerUsername'] = value.username
            converted_data['ownerId'] = value.pk
        elif key == 'comment_count':
            converted_data['commentsCount'] = value
        elif key == 'like_count':
            converted_data['likesCount'] = value
        elif key == 'play_count':
            converted_data['videoPlayCount'] = value
        elif key == 'video_url':
            converted_data['videoUrl'] = value
        elif key == 'view_count':
            converted_data['videoViewCount'] = value
        elif key == 'taken_at':
            converted_data['timestamp'] = format_datetime_to_utc_iso(value)
        elif key == 'resources':
            converted_data['images'] = [resource.thumbnail_url[:] for resource in value]
        elif key == 'product_type':
            converted_data['productType'] = value
        elif key == 'video_duration':
            converted_data['videoDuration'] = value
        elif key == 'sponsor_tags':
            converted_data['isSponsored'] = len(value) > 0

    # set some default values for the keys that are not in the data
    converted_data['firstComment'] = ''
    converted_data['lastestComments'] = []
    converted_data['alt'] = ''
    converted_data['childPosts'] = []
    converted_data['hashtags'] = get_hashtags(converted_data['caption'])
    # print(convert_data['hashtags'])
    # initialize an empty list to store the ordered keys
    ordered_keys = ['id', 'type', 'shortCode', 'caption', 'hashtags', 
                    'mentions', 'url', 'commentsCount', 'firstComment', 
                    'latestComments', 'dimensionsHeight', 'dimensionsWidth', 
                    'displayUrl', 'images', 'videoUrl', 'alt', 
                    'likesCount', 'videoViewCount', 'videoPlayCount', 
                    'timestamp', 'childPosts', 
                    'ownerFullName', 'ownerUsername', 
                    'ownerId', 'productType', 
                    'videoDuration', 
                    'isSponsored']
    # initialize an empty list to store the ordered data items as tuples of (key, value)
    ordered_items = []
    # loop through the ordered keys and add them to the ordered items list with their values from the converted data
    for key in ordered_keys:
        if key in converted_data:
            ordered_items.append((key, converted_data[key]))
        else:
            ordered_items.append((key, None))

    # return the ordered data as a dictionary by using the dict() constructor on the ordered items list
    return dict(ordered_items)

convert_data(info)

data = convert_data(info)
# data

# %%
cl.media_pk_from_url('https://www.instagram.com/p/Cvj02kgxvVx')
# Out:
# 3162603811819156849

# %%
# post_link = 'https://www.instagram.com/p/CvlsTkhRYCH'
# post_id = cl.media_pk_from_url(post_link)

# %%
comments = cl.media_comments(post_id)
# Out:
# Code entered "617793" for just_for_image_scraping (0 attempts by 5 seconds)

# %%
pk='17967088058377489' text='No resolution has been done from HDFC Bank till date.After multiple mails to Sanganer Jaipur branch they are not reverting.Please investigate as I believe the branch is involved in this account.They opened my account without my consent and now they asked me to sign closure why?When I questioned Branch operations manager Pramod then he said "Fir Jo karna hai karlo" is this the way you treat your customer even when you are at fault.This is a violation of my fundamental rights.How can you open and maintain the account without letting me know .I will put forward this to banking ombudsman now.@hdfcbank Case number 29045500' user=UserShort(pk='5753103556', username='itsarpita09', full_name='𝓐𝓻𝓹𝓲𝓽𝓪👁️\u200d🗨️', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/253484358_633718940993729_4653827084205405096_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=K6p73mLer1kAX_eCVgx&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfBAeHpJLP-bKsYrz_v6H427DV9iopdV6poOlWKx99yD4A&oe=64D4EB12&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 8, 32, 1, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18379549189013642' text='It is extremely irritating to keep getting calls for loans. Kindly update your calling list and put me in DND.' user=UserShort(pk='2243284166', username='sonalin_subhadarshini', full_name='sonalin', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/324542928_667116238492652_8838159681391842976_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=Ag8jUcY0LGwAX8_qesA&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfCctZByP-slO23LZAJ5tTGWciWcgqZDDkIOD6k6rn2sxQ&oe=64D57DBC&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 6, 46, 10, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17978381117387109' text='I have an  issue with my account and I tried to contact them for reset my debit card pin, they are not responding' user=UserShort(pk='20162970194', username='singhbhairavi', full_name='singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 4, 26, 26, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17992804675969533' text='Hi Sanjay, thank you for writing to us, our bank official will get back to you. Request your patience in the interim. -Vinay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 2, 51, 19, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='18045722272485567' text='@hdfcbank I have DM the queries kindly do the needful' user=UserShort(pk='58622610905', username='gregory_john_kl05', full_name='𝔾ℝ𝔼𝔾𝕆ℝ𝕐 𝕁𝕆ℍℕ', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355131555_821518522878577_3161244393900629081_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=Q9UhQbejbUwAX8N0RVq&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDQf7L2CxC4YskbJ5BfFqSzwFea2poUw-H-9xhoSLPLtA&oe=64D5A60C&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 23, 8, 35, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='17968183127574870' text='@hdfcbank The reference number was IG04082380169,  can anyone at least respond back to my mail?' user=UserShort(pk='2175367048', username='introverted._.dude_', full_name='Sanjay Krishna', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/313758278_522027156443535_2759749807707565354_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=1OGbHz_GfqsAX8F6aGu&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAGvELTIRGtrLp-BhRJc9OwgG_g8p1i2lz4L6R7BbdkSw&oe=64D66EAB&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 20, 55, 54, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18009360247887876' text="@hdfcbank I had an issue a couple of days back regarding my credit card ,you guys told me to send a mail to a certain mail id with a reference number, got one reply and that's it. No solution even after multiple follow up mails, this is the worst customer service anyone can expect from a bank, as an person who's currently abroad I cannot visit any branches physically, what's the point of customer service if they cannot help me out??" user=UserShort(pk='2175367048', username='introverted._.dude_', full_name='Sanjay Krishna', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/313758278_522027156443535_2759749807707565354_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=1OGbHz_GfqsAX8F6aGu&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAGvELTIRGtrLp-BhRJc9OwgG_g8p1i2lz4L6R7BbdkSw&oe=64D66EAB&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 20, 52, 59, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18008302882882978' text="@gregory_john_kl05 Hi, we'll certainly look into this for you. Please DM us the last four digits of your Credit Card No., along with the registered mobile number & email ID for further assistance. Also, we would request you to not post the details on Public Forum and only in the DM. -Priya, Service Manager" user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 16, 19, 56, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='18194786239260375' text='I have approached towards hdfc bank for credit card jumbo loan closure and the bank team redirect me to customer care assistance from their they redirect me HDFC collection department and they and saying they are helpless to do further to make a loan closure of credit card ( credit card was blocked and customer care associates also helpless) what shall I do, Who can help to further process, actually this much process was not their to giving loans only few conformation through call' user=UserShort(pk='58622610905', username='gregory_john_kl05', full_name='𝔾ℝ𝔼𝔾𝕆ℝ𝕐 𝕁𝕆ℍℕ', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355131555_821518522878577_3161244393900629081_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=Q9UhQbejbUwAX8N0RVq&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDQf7L2CxC4YskbJ5BfFqSzwFea2poUw-H-9xhoSLPLtA&oe=64D5A60C&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 16, 3, 38, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17966532266401695' text="@khandelwal_op Hi, we're happy to help! Visit hdfcbk.io/k/DUvfZkqLnhU to open a Current Account! Once you have filled up the form, we'll call you to assist further. -Anay, Service Manager" user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 14, 28, 26, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='17855171528985004' text='How to open current account @hdfcbank' user=UserShort(pk='51953515717', username='khandelwal_op', full_name='Vivek Khandelwal', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355449492_828270298717645_513239012887114658_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=30YQP5D7a3YAX8Fj2-r&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfC3Pi1IJkocxQMPL3R26VjBXi1rDanDihVAtfWENTNHMw&oe=64D54CA5&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 11, 53, 59, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17939071811694951' text='@getsimpl Thank you for simply being a tap away ;)' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 11, 8, 45, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='18066179722406814' text='@richa9319 Hi Richa, please DM us the complete issue for better assistance. -Anay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 40, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='18363393181070631' text='Koi customer care no. Bhi Nhi h Jo Koi problem Bhi solve kr sake' user=UserShort(pk='9136513921', username='richa9319', full_name='Richa Singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 7, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17977920665235324' text='Frod hai Sab KO' user=UserShort(pk='9136513921', username='richa9319', full_name='Richa Singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 6, 24, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18005622103763256' text='All there for you...but will pull hands when you need them the most..!!' user=UserShort(pk='2048079770', username='oneminuteguitarist', full_name='🅷🅸🅼🅰🅽🆂🅷', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/204203116_181138467291310_3249700164187478340_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=ilko1RVJg0QAX8QJjI4&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfADeUR9uotrKqJM0ZqoXkEJD_3nXcidQZwlRCxY7va_Xw&oe=64D691A0&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 6, 54, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='17976492704267796' text='@hdfcbank Thank you for being that friend whom one can always BANK on 💵 #FriendshipMadeSimpl #HappyFriendshipDay' user=UserShort(pk='1922192494', username='getsimpl', full_name='Simpl', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/357547593_1407782033119306_8599771767860062646_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=i62EygdOmFoAX-AkoM4&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfB1qLVEWo0wRW1bzxWpXkIz5-r0SRS8hv6Dg-3p7l0E0g&oe=64D56827&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 6, 53, 35, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18008154526879267' text='@sam194614 Hi, we regret the inconvenience caused to you. Please DM us the complete issue for better assistance. -Anay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 5, 46, 10, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
pk='18057702925438018' text='❤️' user=UserShort(pk='5065944090', username='annu3617', full_name='Annu Saini', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/332790735_931067597905471_8746011270869947036_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=_KZVbFXRqQUAX8kLBIR&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDVthSZbjf7Bxf0bG_L25iCUQSYRBB3e4xdyrsPKKVrgA&oe=64D52F42&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 5, 15, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
pk='18231617455170141' text='Happy Friendship Day!! 😊♥️' user=UserShort(pk='14285600975', username='abhishekbhardwaj8271', full_name='Abhishek Bhardwaj', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/327956853_2120716888114826_7632661916237344093_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=GYm_xY3W0xkAX-K9_lN&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDOHtJRmpbUcuFzmPDF5NhNGy2VD_I6FL1gHMZvh1CaHw&oe=64D5A9F3&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 4, 42, 58, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0

# %%
for i in comments:
    print(i)
# Out:
# pk='17967088058377489' text='No resolution has been done from HDFC Bank till date.After multiple mails to Sanganer Jaipur branch they are not reverting.Please investigate as I believe the branch is involved in this account.They opened my account without my consent and now they asked me to sign closure why?When I questioned Branch operations manager Pramod then he said "Fir Jo karna hai karlo" is this the way you treat your customer even when you are at fault.This is a violation of my fundamental rights.How can you open and maintain the account without letting me know .I will put forward this to banking ombudsman now.@hdfcbank Case number 29045500' user=UserShort(pk='5753103556', username='itsarpita09', full_name='𝓐𝓻𝓹𝓲𝓽𝓪👁️\u200d🗨️', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/253484358_633718940993729_4653827084205405096_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=K6p73mLer1kAX_eCVgx&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfBAeHpJLP-bKsYrz_v6H427DV9iopdV6poOlWKx99yD4A&oe=64D4EB12&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 8, 32, 1, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18379549189013642' text='It is extremely irritating to keep getting calls for loans. Kindly update your calling list and put me in DND.' user=UserShort(pk='2243284166', username='sonalin_subhadarshini', full_name='sonalin', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/324542928_667116238492652_8838159681391842976_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=Ag8jUcY0LGwAX8_qesA&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfCctZByP-slO23LZAJ5tTGWciWcgqZDDkIOD6k6rn2sxQ&oe=64D57DBC&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 6, 46, 10, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17978381117387109' text='I have an  issue with my account and I tried to contact them for reset my debit card pin, they are not responding' user=UserShort(pk='20162970194', username='singhbhairavi', full_name='singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 4, 26, 26, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17992804675969533' text='Hi Sanjay, thank you for writing to us, our bank official will get back to you. Request your patience in the interim. -Vinay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 7, 2, 51, 19, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='18045722272485567' text='@hdfcbank I have DM the queries kindly do the needful' user=UserShort(pk='58622610905', username='gregory_john_kl05', full_name='𝔾ℝ𝔼𝔾𝕆ℝ𝕐 𝕁𝕆ℍℕ', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355131555_821518522878577_3161244393900629081_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=Q9UhQbejbUwAX8N0RVq&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDQf7L2CxC4YskbJ5BfFqSzwFea2poUw-H-9xhoSLPLtA&oe=64D5A60C&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 23, 8, 35, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='17968183127574870' text='@hdfcbank The reference number was IG04082380169,  can anyone at least respond back to my mail?' user=UserShort(pk='2175367048', username='introverted._.dude_', full_name='Sanjay Krishna', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/313758278_522027156443535_2759749807707565354_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=1OGbHz_GfqsAX8F6aGu&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAGvELTIRGtrLp-BhRJc9OwgG_g8p1i2lz4L6R7BbdkSw&oe=64D66EAB&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 20, 55, 54, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18009360247887876' text="@hdfcbank I had an issue a couple of days back regarding my credit card ,you guys told me to send a mail to a certain mail id with a reference number, got one reply and that's it. No solution even after multiple follow up mails, this is the worst customer service anyone can expect from a bank, as an person who's currently abroad I cannot visit any branches physically, what's the point of customer service if they cannot help me out??" user=UserShort(pk='2175367048', username='introverted._.dude_', full_name='Sanjay Krishna', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/313758278_522027156443535_2759749807707565354_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=1OGbHz_GfqsAX8F6aGu&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfAGvELTIRGtrLp-BhRJc9OwgG_g8p1i2lz4L6R7BbdkSw&oe=64D66EAB&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 20, 52, 59, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18008302882882978' text="@gregory_john_kl05 Hi, we'll certainly look into this for you. Please DM us the last four digits of your Credit Card No., along with the registered mobile number & email ID for further assistance. Also, we would request you to not post the details on Public Forum and only in the DM. -Priya, Service Manager" user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 16, 19, 56, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='18194786239260375' text='I have approached towards hdfc bank for credit card jumbo loan closure and the bank team redirect me to customer care assistance from their they redirect me HDFC collection department and they and saying they are helpless to do further to make a loan closure of credit card ( credit card was blocked and customer care associates also helpless) what shall I do, Who can help to further process, actually this much process was not their to giving loans only few conformation through call' user=UserShort(pk='58622610905', username='gregory_john_kl05', full_name='𝔾ℝ𝔼𝔾𝕆ℝ𝕐 𝕁𝕆ℍℕ', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355131555_821518522878577_3161244393900629081_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=Q9UhQbejbUwAX8N0RVq&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDQf7L2CxC4YskbJ5BfFqSzwFea2poUw-H-9xhoSLPLtA&oe=64D5A60C&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=True, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 16, 3, 38, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17966532266401695' text="@khandelwal_op Hi, we're happy to help! Visit hdfcbk.io/k/DUvfZkqLnhU to open a Current Account! Once you have filled up the form, we'll call you to assist further. -Anay, Service Manager" user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 14, 28, 26, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='17855171528985004' text='How to open current account @hdfcbank' user=UserShort(pk='51953515717', username='khandelwal_op', full_name='Vivek Khandelwal', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/355449492_828270298717645_513239012887114658_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=30YQP5D7a3YAX8Fj2-r&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfC3Pi1IJkocxQMPL3R26VjBXi1rDanDihVAtfWENTNHMw&oe=64D54CA5&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 11, 53, 59, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17939071811694951' text='@getsimpl Thank you for simply being a tap away ;)' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 11, 8, 45, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='18066179722406814' text='@richa9319 Hi Richa, please DM us the complete issue for better assistance. -Anay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 40, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='18363393181070631' text='Koi customer care no. Bhi Nhi h Jo Koi problem Bhi solve kr sake' user=UserShort(pk='9136513921', username='richa9319', full_name='Richa Singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 7, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17977920665235324' text='Frod hai Sab KO' user=UserShort(pk='9136513921', username='richa9319', full_name='Richa Singh', profile_pic_url=HttpUrl('https://instagram.fdel25-2.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fdel25-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=UB8mb-N_5a8AX8b_mIC&edm=AJ9x6zYBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AfAMJh76RoVgv44AswI4Ts_vmDAwVEuwVO3uqqLOzjIleA&oe=64D4F0CF&_nc_sid=65462d', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 8, 6, 24, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18005622103763256' text='All there for you...but will pull hands when you need them the most..!!' user=UserShort(pk='2048079770', username='oneminuteguitarist', full_name='🅷🅸🅼🅰🅽🆂🅷', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/204203116_181138467291310_3249700164187478340_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=ilko1RVJg0QAX8QJjI4&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfADeUR9uotrKqJM0ZqoXkEJD_3nXcidQZwlRCxY7va_Xw&oe=64D691A0&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 6, 54, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='17976492704267796' text='@hdfcbank Thank you for being that friend whom one can always BANK on 💵 #FriendshipMadeSimpl #HappyFriendshipDay' user=UserShort(pk='1922192494', username='getsimpl', full_name='Simpl', profile_pic_url=HttpUrl('https://instagram.fdel8-2.fna.fbcdn.net/v/t51.2885-19/357547593_1407782033119306_8599771767860062646_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=i62EygdOmFoAX-AkoM4&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfB1qLVEWo0wRW1bzxWpXkIz5-r0SRS8hv6Dg-3p7l0E0g&oe=64D56827&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 6, 53, 35, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18008154526879267' text='@sam194614 Hi, we regret the inconvenience caused to you. Please DM us the complete issue for better assistance. -Anay, Service Manager' user=UserShort(pk='2308941538', username='hdfcbank', full_name='HDFC Bank', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/78724609_556254581859936_1189500272188063744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=ktIKaKXHLfsAX_N4PrC&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDFc3ZDD9Wm7MQha-3aWWF_b_UwsYRVPdCKzscxCfFvlw&oe=64D4CAC1&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 5, 46, 10, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=None like_count=None
# pk='18057702925438018' text='❤️' user=UserShort(pk='5065944090', username='annu3617', full_name='Annu Saini', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/332790735_931067597905471_8746011270869947036_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=_KZVbFXRqQUAX8kLBIR&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDVthSZbjf7Bxf0bG_L25iCUQSYRBB3e4xdyrsPKKVrgA&oe=64D52F42&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 5, 15, 29, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0
# pk='18231617455170141' text='Happy Friendship Day!! 😊♥️' user=UserShort(pk='14285600975', username='abhishekbhardwaj8271', full_name='Abhishek Bhardwaj', profile_pic_url=HttpUrl('https://instagram.fdel8-1.fna.fbcdn.net/v/t51.2885-19/327956853_2120716888114826_7632661916237344093_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fdel8-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=GYm_xY3W0xkAX-K9_lN&edm=AId3EpQBAAAA&ccb=7-5&oh=00_AfDOHtJRmpbUcuFzmPDF5NhNGy2VD_I6FL1gHMZvh1CaHw&oe=64D5A9F3&_nc_sid=f5838a', ), profile_pic_url_hd=None, is_private=False, stories=[]) created_at_utc=datetime.datetime(2023, 8, 6, 4, 42, 58, tzinfo=datetime.timezone.utc) content_type='comment' status='Active' has_liked=False like_count=0

# %%
posts = ['https://www.instagram.com/p/CvlsTkhRYCH', "https://www.instagram.com/p/Cvj02kgxvVx/", 'https://www.instagram.com/p/CvhhQc0upI5/', 'https://www.instagram.com/p/CvhWl4Br9hi/']
